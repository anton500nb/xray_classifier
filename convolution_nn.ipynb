# %% [markdown]
# ## NN model for X-ray Body Part Classifier

# %%
import os
from google.colab import drive
import numpy as np
import pandas as pd
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras.regularizers import l2
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, BatchNormalization, AveragePooling2D
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Download CSV files with features (X) and target (y)

# %%
X = pd.read_csv('/content/drive/MyDrive/train_X.csv', header=None)

# %%
y = pd.read_csv('/content/drive/MyDrive/train_y.csv')

# %% [markdown]
# ### Show classes and number of instances in them

# %%
len(y['0'].unique())
# Out:
# 41

# %%
y.groupby(['0'])['0'].count()
# Out:
# 0
# 0      80
# 1      41
# 2      77
# 3     724
# 4       9
# 5      23
# 6      70
# 7      15
# 8      12
# 9      31
# 10     19
# 11    102
# 12     19
# 13     39
# 14    120
# 15     67
# 16     40
# 17     23
# 18     10
# 19      7
# 20     15
# 21     63
# 22      2
# 23     45
# 24     11
# 25      7
# 26     42
# 27      1
# 28      3
# 29      1
# 30      1
# 31      5
# 32      1
# 33      2
# 34      4
# 35      1
# 36      2
# 37      1
# 38      1
# 39      1
# 40      1
# Name: 0, dtype: int64

# %% [markdown]
# ##### The classes are imbalanced, one way to avoid overfitting is to use the RandomOverSampler.

# %%
y = list(y['0'])                                              # make y (target)

# %%
X = pd.DataFrame(X).to_numpy()                                # make X (features)

# %%
ros = RandomOverSampler( sampling_strategy = 'minority')
X_resampled, y_resampled = ros.fit_resample (X, y)            # create similar ones in minority classes

# %%
print('Rows number before RandomOverSampler:', X.shape[0])
print('Rows number after RandomOverSampler:', X_resampled.shape[0])
# Out:
# Rows number before RandomOverSampler: 1738
# Rows number after RandomOverSampler: 2461

# %%
X_resampled = np.reshape(X_resampled, (2461, 84, 84))         # return values to image matrix

# %% [markdown]
# ### Split data for training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size = 0.1, random_state = 45)

# %% [markdown]
# ### Make categories for target

# %%
y_train_cat = keras.utils.to_categorical(y_train, 41)                          
y_test_cat = keras.utils.to_categorical(y_test, 41)

# %% [markdown]
# ### Prepare arrays with features

# %%
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)

# %% [markdown]
# ### Make model

# %%
epo = 52                                               # number of epochs
batch = 32
l2_lambda = 0.0002                                     # L2-regularisation
myOpt = keras.optimizers.Adam(learning_rate = 0.0003)

# %% [markdown]
# ### Create a convolutional neural network

# %%
model = keras.Sequential([
    Conv2D(32, (3,3),
           padding = 'same',
           activation = 'relu',
           kernel_regularizer = l2(l2_lambda),
           input_shape = (84, 84, 1)),
    AveragePooling2D(pool_size = (4, 4)),
    
    Conv2D(64, (3,3), padding = 'same',
           activation='relu'),
    BatchNormalization (),
    AveragePooling2D(pool_size = (4, 4)),
    Flatten(),
    Dense(512, activation = 'relu'),
    Dropout(0.5),
    Dense(41,  activation = 'softmax')
])

model.compile(optimizer = myOpt,
             loss = 'categorical_crossentropy',
             metrics = 'accuracy')


his = model.fit(X_train, y_train_cat,
                batch_size = batch,
                epochs = epo,
                validation_split = 0.1,)

model.evaluate(X_test, y_test_cat)
# Out:
# Epoch 1/52
# 63/63 [==============================] - 1s 10ms/step - loss: 1.7892 - accuracy: 0.5628 - val_loss: 5.6476 - val_accuracy: 0.0586
# Epoch 2/52
# 63/63 [==============================] - 0s 7ms/step - loss: 1.2257 - accuracy: 0.6827 - val_loss: 2.3453 - val_accuracy: 0.4730
# Epoch 3/52
# 63/63 [==============================] - 0s 7ms/step - loss: 1.0755 - accuracy: 0.7209 - val_loss: 1.6682 - val_accuracy: 0.6532
# Epoch 4/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.9794 - accuracy: 0.7405 - val_loss: 1.5365 - val_accuracy: 0.4189
# Epoch 5/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8919 - accuracy: 0.7631 - val_loss: 1.1728 - val_accuracy: 0.7117
# Epoch 6/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8366 - accuracy: 0.7736 - val_loss: 1.0933 - val_accuracy: 0.7432
# Epoch 7/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8112 - accuracy: 0.7856 - val_loss: 1.1442 - val_accuracy: 0.7162
# Epoch 8/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.7224 - accuracy: 0.7922 - val_loss: 1.1560 - val_accuracy: 0.7342
# Epoch 9/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6869 - accuracy: 0.8198 - val_loss: 1.6793 - val_accuracy: 0.4189
# Epoch 10/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6671 - accuracy: 0.8158 - val_loss: 1.1010 - val_accuracy: 0.7207
# Epoch 11/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5856 - accuracy: 0.8333 - val_loss: 1.1856 - val_accuracy: 0.7162
# Epoch 12/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5801 - accuracy: 0.8268 - val_loss: 1.2651 - val_accuracy: 0.7252
# Epoch 13/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5109 - accuracy: 0.8579 - val_loss: 0.9802 - val_accuracy: 0.7613
# Epoch 14/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4636 - accuracy: 0.8660 - val_loss: 0.9797 - val_accuracy: 0.7568
# Epoch 15/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4387 - accuracy: 0.8790 - val_loss: 1.1477 - val_accuracy: 0.5045
# Epoch 16/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4066 - accuracy: 0.8825 - val_loss: 1.0981 - val_accuracy: 0.7297
# Epoch 17/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.3661 - accuracy: 0.8976 - val_loss: 0.9891 - val_accuracy: 0.7793
# Epoch 18/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.3609 - accuracy: 0.8966 - val_loss: 1.1680 - val_accuracy: 0.7252
# Epoch 19/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.3079 - accuracy: 0.9142 - val_loss: 0.8527 - val_accuracy: 0.8198
# Epoch 20/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2778 - accuracy: 0.9142 - val_loss: 0.8563 - val_accuracy: 0.8063
# Epoch 21/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2849 - accuracy: 0.9197 - val_loss: 0.9835 - val_accuracy: 0.8018
# Epoch 22/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2507 - accuracy: 0.9252 - val_loss: 1.3257 - val_accuracy: 0.5135
# Epoch 23/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2160 - accuracy: 0.9438 - val_loss: 1.0295 - val_accuracy: 0.7658
# Epoch 24/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1983 - accuracy: 0.9498 - val_loss: 0.7992 - val_accuracy: 0.8018
# Epoch 25/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1954 - accuracy: 0.9438 - val_loss: 0.9944 - val_accuracy: 0.7928
# Epoch 26/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1831 - accuracy: 0.9563 - val_loss: 0.8854 - val_accuracy: 0.8153
# Epoch 27/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1624 - accuracy: 0.9583 - val_loss: 0.8368 - val_accuracy: 0.8288
# Epoch 28/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1645 - accuracy: 0.9548 - val_loss: 1.2195 - val_accuracy: 0.7342
# Epoch 29/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1842 - accuracy: 0.9533 - val_loss: 0.9563 - val_accuracy: 0.7748
# Epoch 30/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1316 - accuracy: 0.9664 - val_loss: 0.7649 - val_accuracy: 0.8559
# Epoch 31/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1195 - accuracy: 0.9669 - val_loss: 0.9886 - val_accuracy: 0.8018
# Epoch 32/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1191 - accuracy: 0.9714 - val_loss: 1.0557 - val_accuracy: 0.7883
# Epoch 33/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1127 - accuracy: 0.9709 - val_loss: 0.8173 - val_accuracy: 0.8333
# Epoch 34/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1061 - accuracy: 0.9729 - val_loss: 1.0584 - val_accuracy: 0.7703
# Epoch 35/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1092 - accuracy: 0.9769 - val_loss: 1.2848 - val_accuracy: 0.7297
# Epoch 36/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0835 - accuracy: 0.9839 - val_loss: 1.0507 - val_accuracy: 0.7748
# Epoch 37/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0758 - accuracy: 0.9794 - val_loss: 0.9102 - val_accuracy: 0.8288
# Epoch 38/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0758 - accuracy: 0.9829 - val_loss: 0.9525 - val_accuracy: 0.8063
# Epoch 39/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0679 - accuracy: 0.9859 - val_loss: 1.0796 - val_accuracy: 0.7973
# Epoch 40/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0577 - accuracy: 0.9885 - val_loss: 0.9179 - val_accuracy: 0.8108
# Epoch 41/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0588 - accuracy: 0.9864 - val_loss: 0.7818 - val_accuracy: 0.8378
# Epoch 42/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0567 - accuracy: 0.9859 - val_loss: 0.8809 - val_accuracy: 0.8333
# Epoch 43/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0532 - accuracy: 0.9895 - val_loss: 0.8802 - val_accuracy: 0.8198
# Epoch 44/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0505 - accuracy: 0.9910 - val_loss: 1.0740 - val_accuracy: 0.7928
# Epoch 45/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0541 - accuracy: 0.9910 - val_loss: 1.1253 - val_accuracy: 0.7883
# Epoch 46/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0503 - accuracy: 0.9910 - val_loss: 1.2263 - val_accuracy: 0.7748
# Epoch 47/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0513 - accuracy: 0.9900 - val_loss: 0.9125 - val_accuracy: 0.8333
# Epoch 48/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0404 - accuracy: 0.9960 - val_loss: 0.9539 - val_accuracy: 0.8333
# Epoch 49/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0415 - accuracy: 0.9905 - val_loss: 1.0163 - val_accuracy: 0.8063
# Epoch 50/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0327 - accuracy: 0.9945 - val_loss: 0.9106 - val_accuracy: 0.8423
# Epoch 51/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0345 - accuracy: 0.9935 - val_loss: 2.1112 - val_accuracy: 0.4910
# Epoch 52/52
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0330 - accuracy: 0.9960 - val_loss: 0.8633 - val_accuracy: 0.8423
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8171 - accuracy: 0.8664
# [0.8171331882476807, 0.8663967847824097]

# %%
predictions = model.predict(X_test)
print('Real values: \n', np.array(y_test))
print('Predict values: \n', y_pred)
print('Accuracy score: ', accuracy_score(y_test, y_pred))
# Out:
# Real values:
#  [27 11  3  3  1  3 26 27 27  3 27  0 15  3  3  3  0  3 27  3  3 27 14 27
#  16  1  3  3 27  3  2 16  3  3  3  0 27 23  3  1 11 11 23  6 27  0 11 27
#  23  3  3 27 27  0 27 27 27  0  3  3  3  2 14 21 27  3  0  3 27 23 11  3
#   3  3 27 17  3  3 27  3  3 27  9  3  3 16 14 27  3  3  3  3 27 19  3 21
#   3 13  3  0 27  3 26 11  3 23  2 16  6  3 11  3 10  1 27 11 27 20  3 27
#   1 27  3  3 11 32  2 27  3  3  3  3  2 27  3 36  2  0 17 23 27 27 27 26
#  27  3  3 27 27 27  6 11  3 27 11  3 27  3 14 27  3  3 27 11 27 23 27 13
#   3  3 21 19 21  6  3  3 27 11 11 27 27 11 13 27 17  3 27  3  3 11  7 27
#  27  5  3 14 26  3  3 27  6 27 27  3 26 27 27  3 14  3  2  0 14 27  1 11
#  26  3  3  3 21 27  3 34 27 27 27  3 27  3  3 27 27 21  3  3 27  3 26  3
#  21  3 27 35  3 11 11]
# Predict values:
#  [27 11  3  3  6  3 26 27 27  3 27 11 15  3  3  3  0  3 27  3  3 27 14 27
#  16  1  3  3 27  3 10 16  3  3  3  0 27 14  3  1 11 11 23  7 27  3  5 27
#  23  3  3 27 27  0 27 27 27  0  3  3  3  3 14  1 27  3  0  3 27 23 11  3
#   3  3 27 17  3  3 27  3  3 27 26  3  3 13 14 27  3  3  3  3 27  8  3 21
#   3  0  3  0 27  3 26 11  3 23  2 16  6  3 11  3 10  1 27 11 27  3  3 27
#   3 27  3  3 11  7  2 27  3  3  3  3  2 27  3 11  2 10 17 23 27 27 27 26
#  27  3  3 27 27 27 26 11  3 27 11  3 27  3 14 27  3  3 27  0 27 19 27 11
#   3  3  3 19 21  9  3  3 27 11  3 27 27 11 13 27 11  3 27  3  3 11  7 27
#  27  5  3 14 26  3  3 27  6 27 27  3 26 27 27  3 13  3  2  0 14 27  1 11
#   9  3 15  3 21 27  3 10 27 27 27  3 27  3  3 27 27  6  3  3 27  3  9  3
#  21  3 27 15  3 11 11]
# Accuracy score:  0.8663967611336032

# %% [markdown]
# ##### The model predicts X-ray Body Part with an accuracy of 86.6%.
