# %% [markdown]
# ## Make prediction for X-ray Body Part Classifier competition

# %%
import os
from google.colab import drive
import numpy as np
import pandas as pd
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras.regularizers import l2
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, BatchNormalization, AveragePooling2D
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
import json

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Download CSV files with features (X) and target (y)

# %%
X = pd.read_csv('/content/drive/MyDrive/train_X.csv',  header=None)

# %%
y = pd.read_csv('/content/drive/MyDrive/train_y.csv')

# %% [markdown]
# ### Show classes and number of instances in them

# %%
len(y['0'].unique())
# Out:
# 41

# %%
y.groupby(['0'])['0'].count()
# Out:
# 0
# 0      80
# 1      41
# 2      77
# 3     724
# 4       9
# 5      23
# 6      70
# 7      15
# 8      12
# 9      31
# 10     19
# 11    102
# 12     19
# 13     39
# 14    120
# 15     67
# 16     40
# 17     23
# 18     10
# 19      7
# 20     15
# 21     63
# 22     45
# 23     42
# 24     11
# 25      5
# 26      1
# 27      1
# 28      7
# 29      4
# 30      2
# 31      1
# 32      1
# 33      2
# 34      3
# 35      1
# 36      1
# 37      2
# 38      1
# 39      1
# 40      1
# Name: 0, dtype: int64

# %% [markdown]
# ##### The classes are imbalanced, one way to avoid overfitting is to use the RandomOverSampler.

# %%
y=list(y['0'])

# %%
X = pd.DataFrame(X).to_numpy()

# %%
ros = RandomOverSampler( sampling_strategy = 'minority')
X_resampled, y_resampled = ros.fit_resample(X, y)           # create similar ones in minority classes

# %%
print('Rows number before RandomOverSampler:', X.shape[0])
print('Rows number after RandomOverSampler:', X_resampled.shape[0])
# Out:
# Rows number before RandomOverSampler: 1738
# Rows number after RandomOverSampler: 2461

# %%
X_resampled = np.reshape(X_resampled, (2461, 84, 84))       # return values to image matrix

# %% [markdown]
# ### Split data for training and testing

# %%
X_train,X_test,y_train,y_test = train_test_split(X_resampled, y_resampled, test_size = 0.1, random_state = 92)

# %% [markdown]
# ### Make categories for target

# %%
y_train_cat = keras.utils.to_categorical(y_train, 41)                          
y_test_cat = keras.utils.to_categorical(y_test, 41)

# %%
y_cat = keras.utils.to_categorical(y_resampled, 41)

# %% [markdown]
# ### Prepare arrays with features

# %%
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)

# %%
X = np.expand_dims(X_resampled, axis=3)

# %% [markdown]
# ### Make model

# %%
epo = 52                                               # number of epochs
batch = 32
l2_lambda = 0.0006                                     # L2-regularisation
myOpt = keras.optimizers.Adam(learning_rate = 0.0003)

# %% [markdown]
# ### Create a convolutional neural network

# %%
model = keras.Sequential([
    Conv2D(32, (3,3),
           padding = 'same',
           activation = 'relu',
           kernel_regularizer = l2(l2_lambda),
           input_shape = (84, 84, 1)),
    BatchNormalization (),
    AveragePooling2D(pool_size = (4, 4)),
    Conv2D(64, (3,3), padding = 'same',
           activation='relu'),
    BatchNormalization (),
    AveragePooling2D(pool_size = (4, 4)),
    Flatten(),
    Dense(256, activation = 'relu'),
    Dropout(0.5),
    Dense(41,  activation = 'softmax')
])

model.compile(optimizer = myOpt,
             loss = 'categorical_crossentropy',
             metrics = 'accuracy')


his = model.fit(X, y_cat,               # make the model on all data, without separation into tests, so as not to lose cases
                batch_size = batch,
                epochs = epo,
                validation_split = 0.1,)

model.evaluate(X_test, y_test_cat)
# Out:
# Epoch 1/52
# 70/70 [==============================] - 13s 15ms/step - loss: 1.8601 - accuracy: 0.5727 - val_loss: 6.7307 - val_accuracy: 0.0000e+00
# Epoch 2/52
# 70/70 [==============================] - 1s 8ms/step - loss: 1.2734 - accuracy: 0.6838 - val_loss: 3.9729 - val_accuracy: 0.0000e+00
# Epoch 3/52
# 70/70 [==============================] - 1s 8ms/step - loss: 1.1191 - accuracy: 0.7191 - val_loss: 0.7712 - val_accuracy: 1.0000
# Epoch 4/52
# 70/70 [==============================] - 1s 8ms/step - loss: 1.0007 - accuracy: 0.7394 - val_loss: 0.0671 - val_accuracy: 1.0000
# Epoch 5/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.9093 - accuracy: 0.7692 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 6/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.8340 - accuracy: 0.7846 - val_loss: 0.0363 - val_accuracy: 1.0000
# Epoch 7/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7329 - accuracy: 0.8008 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 8/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6787 - accuracy: 0.8085 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 9/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6118 - accuracy: 0.8342 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 10/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5848 - accuracy: 0.8379 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 11/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5399 - accuracy: 0.8500 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 12/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4901 - accuracy: 0.8604 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 13/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4475 - accuracy: 0.8722 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 14/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4366 - accuracy: 0.8803 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 15/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3898 - accuracy: 0.8925 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 16/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3651 - accuracy: 0.8957 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 17/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3300 - accuracy: 0.9083 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 18/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3309 - accuracy: 0.9029 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 19/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2899 - accuracy: 0.9201 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 20/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2674 - accuracy: 0.9255 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 21/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2651 - accuracy: 0.9295 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 22/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2396 - accuracy: 0.9363 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 23/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2161 - accuracy: 0.9426 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 24/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2058 - accuracy: 0.9485 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 25/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1951 - accuracy: 0.9440 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 26/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1709 - accuracy: 0.9490 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 27/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1774 - accuracy: 0.9517 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 28/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1503 - accuracy: 0.9625 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 29/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1461 - accuracy: 0.9589 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 30/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1374 - accuracy: 0.9661 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 31/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1470 - accuracy: 0.9603 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 32/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1355 - accuracy: 0.9684 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 33/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1333 - accuracy: 0.9648 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 34/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1014 - accuracy: 0.9752 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 35/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1172 - accuracy: 0.9706 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 36/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1008 - accuracy: 0.9747 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 37/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1057 - accuracy: 0.9715 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 38/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0826 - accuracy: 0.9797 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 39/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0845 - accuracy: 0.9824 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 40/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0821 - accuracy: 0.9774 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 41/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0727 - accuracy: 0.9810 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 42/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0669 - accuracy: 0.9846 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 43/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0724 - accuracy: 0.9828 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 44/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0731 - accuracy: 0.9819 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 45/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0633 - accuracy: 0.9837 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 46/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0604 - accuracy: 0.9851 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 47/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0491 - accuracy: 0.9887 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 48/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0500 - accuracy: 0.9892 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 49/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0398 - accuracy: 0.9932 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 50/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0494 - accuracy: 0.9896 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 51/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0485 - accuracy: 0.9905 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 52/52
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0558 - accuracy: 0.9842 - val_loss: 0.0010 - val_accuracy: 1.0000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0356 - accuracy: 0.9919
# [0.035626694560050964, 0.9919028282165527]

# %% [markdown]
# ##### The result is high because the algorithm has seen the test set.

# %% [markdown]
# ### Make file with the prediction for competition

# %%
comp = pd.read_csv('/content/drive/MyDrive/comp.csv',  header=None)       # dataset with images for prediction

# %%
comp = pd.DataFrame(comp).to_numpy()                                    # prepare data
comp = np.reshape(comp, (743, 84, 84)) 
comp = np.expand_dims(comp, axis=3)

# %%
test_df = pd.read_csv('/content/drive/MyDrive/sample_submission.csv')   # download the sample Kaggle file to submit to the competition

# %%
test_df = test_df.drop(['Target'], axis=1)                              # drop column with samples

# %%
with open('/content/codes.json', 'r') as j:                             # download file with multivalue codes
     codes = json.loads(j.read())

# %%
predictions = model.predict(comp)                                       # make prediction
y_pred = np.argmax(predictions, axis=1)
len(y_pred)
# Out:
# 743

# %%
pred_list=[]                                                            # decoding 'y'
for i in y_pred:
  if str(i) in codes.keys():
    pred_list.append(' '.join(codes[str(i)]))
  else:
    pred_list.append(str(i))

# %%
test_df['Target'] = pred_list                                           # add to 'sample_submission'

# %%
test_df.Target.value_counts()
# Out:
# 3        355
# 14        57
# 11        50
# 21        40
# 0         39
# 6         35
# 15        21
# 1         20
# 2         17
# 9         16
# 13 20     15
# 16        11
# 9 21      11
# 17         8
# 7          8
# 13         8
# 4          5
# 5          5
# 12         4
# 19         3
# 20         3
# 10         3
# 1 6        2
# 8          2
# 18         2
# 0 3        1
# 0 15       1
# 1 12       1
# Name: Target, dtype: int64

# %%
pd.DataFrame(test_df).to_csv("sample_submission.csv", header = True , index = False)   # save and send

# %% [markdown]
# ##### My result in competitions is 82.6%
